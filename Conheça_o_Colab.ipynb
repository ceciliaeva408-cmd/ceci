# %% [markdown]
# <a href="https://colab.research.google.com/github/ceciliaeva408-cmd/ceci/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nova seção

# %% [markdown]
# BLOCO 1

# %%
nome = input("Digite seu nome:")
print("Seja bem-vindo(a),", nome)
# Out:
# Digite seu nome:eva
# Seja bem-vindo(a), eva

# %%
idade = int(input("Digite sua idade: "))
print("Sua idade é:", idade)
# Out:
# Digite sua idade: 22
# Sua idade é: 22

# %%
nome = input("Digite seu nome: ")
curso = input("Digite seu curso: ")

print("Nome:", nome)
print("Curso:", curso)
# Out:
# Digite seu nome: eva
# Digite seu curso: t.i
# Nome: eva
# Curso: t.i

# %%
numero = int(input("Digite um número inteiro: "))
dobro = numero * 2

print("O dobro é:", dobro)
# Out:
# Digite um número inteiro: 5
# O dobro é: 10

# %%
num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))

soma = num1 + num2
print("a soma é:", soma)
# Out:
# Digite o primeiro número: 3
# Digite o segundo número: 2
# a soma é: 5.0

# %%
valor = float(input("Digite um valor em reais: "))

print(f"O valor informado foi R${valor:.2f}")
# Out:
# Digite um valor em reais: 300
# O valor informado foi R$300.00

# %%
produto = input("Digite o nome do produto:")
preco = float(input("Digite o preço do produto:"))

print("Produto:", produto)
print("Preço: R$", preco)
# Out:
# Digite o nome do produto:pipoca
# Digite o preço do produto:5
# Produto: pipoca
# Preço: R$ 5.0

# %%
salario = float(input("Digite o salário: "))
print("O salário do funcionário é:", salario)
# Out:
# Digite o salário: 1600
# O salário do funcionário é: 1600.0

# %%
altura = float(input("Digite a altura: "))
peso = float(input("Digite o peso: "))

print("Altura:", altura)
print("Peso:", peso)
# Out:
# Digite a altura: 1.60
# Digite o peso: 55
# Altura: 1.6
# Peso: 55.0

# %%
cidade = input("Digite o nome da cidade: ")
print("Você mora em", cidade)
# Out:
# Digite o nome da cidade: Salvador
# Você mora em Salvador

# %% [markdown]
# BLOCO 2

# %%
n1 = float(input("Nota 1: "))
n2 = float(input("Nota 2: "))

media = (n1 + n2) / 2
print("Média:", media)
# Out:
# Nota 1: 50
# Nota 2: 60
# Média: 55.0

# %%
salario = float(input("Salário: "))
bonus = salario * 0.10

print("Salário com bônus:", salario + bonus)
# Out:
# Salário: 1750
# Salário com bônus: 1925.0

# %%
quantidade = int(input("Quantidade: "))
preco = float(input("Preço: "))

total = quantidade * preco
print("Total:", total)
# Out:
# Quantidade: 300
# Preço: 12
# Total: 3600.0

# %%
ano = int(input("Ano de nascimento: "))
idade = 2026 - ano

print("Idade:", idade)
# Out:
# Ano de nascimento: 2004
# Idade: 22

# %%
km = float(input("Km rodados: "))
litros = float(input("Litros gastos: "))

consumo = km / litros
print("Consumo:", consumo, "km/l")
# Out:
# Km rodados: 37
# Litros gastos: 2
# Consumo: 18.5 km/l

# %%
preco = float(input("Preço: "))
desconto = preco * 0.20

print("Valor com desconto:", preco - desconto)
# Out:
# Preço: 20
# Valor com desconto: 16.0

# %%
valor = float(input("Valor da conta: "))
taxa = valor * 0.10

print("Valor final:", valor + taxa)
# Out:
# Valor da conta: 500
# Valor final: 550.0

# %%
base = float(input("Base: "))
altura = float(input("Altura: "))

area = base * altura
print("Área:", area)
# Out:
# Base: 7
# Altura: 3
# Área: 21.0

# %% [markdown]
# BLOCO 3

# %%
idade = int(input("Idade: "))

if idade >= 18:
    print("Maior de idade")
else:
    print("Menor de idade")
# Out:
# Idade: 23
# Maior de idade

# %%
media = float(input("Média: "))

if media >= 7:
    print("Aprovado")
else:
    print("Reprovado")
# Out:
# Média: 90
# Aprovado

# %%
media = float(input("Média: "))

if media >= 7:
    print("Aprovado")
elif media >= 5:
    print("Recuperação")
else:
    print("Reprovado")
# Out:
# Média: 6
# Recuperação

# %%
usuario = input("Usuário: ")
senha = input("Senha: ")

if usuario == "admin" and senha == "1234":
    print("Login correto")
else:
    print("Login inválido")
# Out:
# Usuário: carlabresa
# Senha: 09876
# Login inválido

# %%
preco = float(input("Preço: "))
forma = input("Forma (avista/parcelado): ")

if forma == "avista":
    print("Valor com desconto:", preco * 0.9)
else:
    print("Valor normal:", preco)
# Out:
# Preço: 70
# Forma (avista/parcelado): parcelado
# Valor normal: 70.0

# %%
renda = float(input("Renda: "))
valor = float(input("Valor do empréstimo: "))

if valor <= renda * 5:
    print("Aprovado")
else:
    print("Negado")
# Out:
# Renda: 1600
# Valor do empréstimo: 2000
# Aprovado

# %%
idade = int(input("Idade: "))

if idade <= 12:
    print("Criança")
elif idade <= 17:
    print("Adolescente")
elif idade <= 59:
    print("Adulto")
else:
    print("Idoso")
# Out:
# Idade: 10
# Criança

# %%
media = float(input("Média: "))

if media >= 9:
    print("Aprovado com excelência")
elif media >= 7:
    print("Aprovado")
elif media >= 5:
    print("Recuperação")
else:
    print("Reprovado")
# Out:
# Média: 9
# Aprovado com excelência

# %%
num = float(input("Número: "))

if num > 0:
    print("Positivo")
elif num < 0:
    print("Negativo")
else:
    print("Zero")
# Out:
# Número: 3
# Positivo

# %%
num = int(input("Número: "))

if num % 2 == 0:
    print("Par")
else:
    print("Ímpar")
# Out:
# Número: 7
# Ímpar

# %%
distancia = float(input("Distância: "))

if distancia <= 5:
    print("Valor: R$10")
elif distancia <= 10:
    print("Valor: R$20")
elif distancia <= 20:
    print("Valor: R$30")
else:
    print("Valor: R$50")
# Out:
# Distância: 15
# Valor: R$30
